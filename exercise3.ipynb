# %% [markdown]
# # Preprocessing

# %%
# %pip install pydriller
# Out:
# Requirement already satisfied: pydriller in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (2.5.1)
# Requirement already satisfied: gitpython in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (3.1.40)
# Requirement already satisfied: pytz in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (2023.3.post1)
# Requirement already satisfied: types-pytz in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (2023.3.1.1)
# Requirement already satisfied: lizard in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (1.17.10)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from gitpython->pydriller) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->pydriller) (5.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydriller import Repository
import os
import datetime as dt
from datetime import timedelta

# %%
# Clone code from the repo and save it for code portability -> via normal git clone
url = "https://github.com/apache/kafka"
repo_path = os.path.join(os.getcwd(), 'kafka')
clone = f"git clone {url} {repo_path}" 

os.system(clone) # Cloning
# Out:
# 128

# %%
# checkout the tag 3.6.0
os.chdir(repo_path)
os.system("git checkout 3.6.0")
# back to the "home" folder
os.chdir("..")

# %%
from_tag = "3.5.1"
from_date=dt.datetime(2023, 7, 14, 18, 51, 0)

to_tag = "3.6.0"
to_date=dt.datetime(2023, 9, 29, 6, 56, 0)

# Using datetimes of the releases, since tags don't yield any commits
# Open question 
# repo = Repository(path_to_repo=repo_path, from_tag=to_tag, to_tag=from_tag)
repo = Repository(path_to_repo=repo_path, since=from_date, to=to_date)

# %% [markdown]
# # Exercise 3

# %%
# return array of files which were modified in following time horizon given the from_time
from datetime import timedelta
from collections import defaultdict

def get_mod_files_between(from_time, windows):
    results = {window: defaultdict(int) for window in windows}

    # Iterate through commits once, checking against each window
    for commit in Repository(path_to_repo=repo_path, since=from_time, to=from_time+timedelta(hours=168)).traverse_commits():
        for file in commit.modified_files:
            filename = file.new_path if file.new_path else file.old_path

            if(not filename.endswith(".java")):
                continue


            # append into each suitable window
            for window in windows:
                window_end_time = from_time + timedelta(hours=window)
                if from_time <= commit.committer_date <= window_end_time:
                        results[window][filename] += 1

    # Convert defaultdict to regular dict for final output
    return {window: dict(file_dict) for window, file_dict in results.items()}

# %%
from collections import Counter
from datetime import datetime
#iterate over each changes from the start of the repo?
# -> look in a windof of next commits within a window of X
# -> calculate the number of changes in this window

file_connections = defaultdict(lambda: {24: {}, 48: {}, 72: {}, 168: {}})
windows = [24, 48, 72, 168]
i = 1

all_commits = Repository(path_to_repo=repo_path, 
                         only_modifications_with_file_types=['.java'],
                         since=datetime(2023, 8, 20, 17, 59, 0)
                         ).traverse_commits()

for commit in all_commits:
    for file in commit.modified_files:
        filename = file.new_path if file.new_path else file.old_path

        #if not java files -> skip
        if(not filename.endswith(".java")):
            continue
        file_dict = file_connections[filename]

        mod_files_results = get_mod_files_between(commit.committer_date, windows)
        for window, mod_list in mod_files_results.items():
            file_dict[window] = dict(Counter(file_dict[window]) + Counter(mod_list))
                
    # i -= 1
    # if i <= 0:
    #     break

# %%
#This function has 2 assumptions 
#   -> we don't remove modification of the file itself in the array
#   -> we have an causality -> given modification of file 1 how many times was FILE2 modified in the time window
def generate_commit_structure(file_connections):
    output = {}
    # Collect data for each file pair across all time windows
    for file, time_windows in file_connections.items():
        for time_window, connections in time_windows.items():
            for connected_file, count in connections.items():
                file_pair = tuple(sorted([file, connected_file]))
                if file_pair not in output:
                    output[file_pair] = {}
                if time_window not in output[file_pair]:
                    output[file_pair][time_window] = 0
                output[file_pair][time_window] += count

    # Format the output
    formatted_output = []
    for file_pair, time_windows in output.items():
        coupled_commits = [{"time_window": tw, "commit_count": count} for tw, count in time_windows.items()]
        formatted_output.append({
            "file_pair": list(file_pair),
            "coupled_commits": coupled_commits
        })

    return formatted_output

# %%
#Test the transformation into Slides type of code
file_connections_test = {"FILE1": {12: {"FILE2": 1, "FILE3": 1, "FILE4": 5},
                                   24: {"FILE2": 1, "FILE3": 1, "FILE4": 5}},
                        "FILE4": {12: {"FILE2": 1, "FILE3": 1, "FILE41": 5}}}
new_structure = generate_commit_structure(file_connections_test)
new_structure
# Out:
# [{'file_pair': ['FILE1', 'FILE2'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 1},
#    {'time_window': 24, 'commit_count': 1}]},
#  {'file_pair': ['FILE1', 'FILE3'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 1},
#    {'time_window': 24, 'commit_count': 1}]},
#  {'file_pair': ['FILE1', 'FILE4'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 5},
#    {'time_window': 24, 'commit_count': 5}]},
#  {'file_pair': ['FILE2', 'FILE4'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 1}]},
#  {'file_pair': ['FILE3', 'FILE4'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 1}]},
#  {'file_pair': ['FILE4', 'FILE41'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 5}]}]

# %%
# transform repository into the structure for the slides
new_structure = generate_commit_structure(file_connections)

new_structure
# Out:
# [{'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\metadata\\storage\\TopicBasedRemoteLogMetadataManagerConfig.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['clients\\src\\main\\java\\org\\apache\\kafka\\common\\config\\TopicConfig.java',
#    'core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogMetadataManager.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogManagerConfig.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\TieredStorageTestHarness.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ConsumeAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\CreateTopicAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectBrokerInISRAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectLeaderAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectTopicIdToMatchInRemoteStorageAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectUserTopicMappedToMetadataPartitionsAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ProduceAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\java\\kafka\\log\\remote\\RemoteLogManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\metadata\\storage\\TopicBasedRemoteLogMetadataManagerConfig.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['clients\\src\\main\\java\\org\\apache\\kafka\\common\\config\\TopicConfig.java',
#    'core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogMetadataManager.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogManagerConfig.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\TieredStorageTestHarness.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ConsumeAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\CreateTopicAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectBrokerInISRAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectLeaderAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectTopicIdToMatchInRemoteStorageAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectUserTopicMappedToMetadataPartitionsAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ProduceAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\test\\java\\kafka\\log\\remote\\RemoteLogManagerTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 3},
#    {'time_window': 48, 'commit_count': 3},
#    {'time_window': 72, 'commit_count': 3},
#    {'time_window': 168, 'commit_count': 3}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 3},
#    {'time_window': 48, 'commit_count': 3},
#    {'time_window': 72, 'commit_count': 3},
#    {'time_window': 168, 'commit_count': 3}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 3},
#    {'time_window': 48, 'commit_count': 3},
#    {'time_window': 72, 'commit_count': 3},
#    {'time_window': 168, 'commit_count': 3}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 3},
#    {'time_window': 48, 'commit_count': 3},
#    {'time_window': 72, 'commit_count': 3},
#    {'time_window': 168, 'commit_count': 3}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\metadata\\storage\\TopicBasedRemoteLogMetadataManagerConfig.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['clients\\src\\main\\java\\org\\apache\\kafka\\common\\config\\TopicConfig.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 3},
#    {'time_window': 48, 'commit_count': 3},
#    {'time_window': 72, 'commit_count': 3},
#    {'time_window': 168, 'commit_count': 3}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogMetadataManager.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 3},
#    {'time_window': 48, 'commit_count': 3},
#    {'time_window': 72, 'commit_count': 3},
#    {'time_window': 168, 'commit_count': 3}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogManagerConfig.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 3},
#    {'time_window': 48, 'commit_count': 3},
#    {'time_window': 72, 'commit_count': 3},
#    {'time_window': 168, 'commit_count': 3}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\TieredStorageTestHarness.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ConsumeAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\CreateTopicAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectBrokerInISRAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectLeaderAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectTopicIdToMatchInRemoteStorageAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectUserTopicMappedToMetadataPartitionsAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ProduceAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java',
#    'storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteStorageManager.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\metadata\\storage\\TopicBasedRemoteLogMetadataManagerConfig.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['clients\\src\\main\\java\\org\\apache\\kafka\\common\\config\\TopicConfig.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogMetadataManager.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogManagerConfig.java',
#    'storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\TieredStorageTestHarness.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ConsumeAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\CreateTopicAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectBrokerInISRAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectLeaderAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectTopicIdToMatchInRemoteStorageAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectUserTopicMappedToMetadataPartitionsAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ProduceAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\storage\\internals\\log\\RemoteIndexCache.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\metadata\\storage\\TopicBasedRemoteLogMetadataManagerConfig.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['clients\\src\\main\\java\\org\\apache\\kafka\\common\\config\\TopicConfig.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogMetadataManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogManagerConfig.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\TieredStorageTestHarness.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ConsumeAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\CreateTopicAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectBrokerInISRAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectLeaderAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectTopicIdToMatchInRemoteStorageAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectUserTopicMappedToMetadataPartitionsAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ProduceAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\metadata\\storage\\TopicBasedRemoteLogMetadataManagerConfig.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['clients\\src\\main\\java\\org\\apache\\kafka\\common\\config\\TopicConfig.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\api\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogMetadataManager.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\main\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\RemoteLogManagerConfig.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\BrokerLocalStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\TieredStorageTestHarness.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ConsumeAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\CreateTopicAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectBrokerInISRAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectLeaderAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectTopicIdToMatchInRemoteStorageAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ExpectUserTopicMappedToMetadataPartitionsAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ProduceAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\server\\log\\remote\\storage\\LocalTieredStorageTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
# ...
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ProduceAction.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ProduceAction.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ReassignReplicaAction.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\actions\\ShrinkReplicaAction.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\integration\\TransactionsWithTieredStoreTest.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\ActionUtils.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\TieredStorageTestUtils.java'],
#   'coupled_commits': [{'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 2},
#    {'time_window': 48, 'commit_count': 2},
#    {'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\main\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResource.java',
#    'streams\\src\\main\\java\\org\\apache\\kafka\\streams\\StreamsConfig.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['connect\\runtime\\src\\test\\java\\org\\apache\\kafka\\connect\\runtime\\rest\\resources\\ConnectorPluginsResourceTest.java',
#    'streams\\src\\main\\java\\org\\apache\\kafka\\streams\\StreamsConfig.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java',
#    'metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['metadata\\src\\main\\java\\org\\apache\\kafka\\controller\\ActivationRecordsGenerator.java',
#    'streams\\src\\main\\java\\org\\apache\\kafka\\streams\\StreamsConfig.java'],
#   'coupled_commits': [{'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['streams\\src\\main\\java\\org\\apache\\kafka\\streams\\StreamsConfig.java',
#    'streams\\src\\main\\java\\org\\apache\\kafka\\streams\\StreamsConfig.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\BrokerLocalStorage.java',
#    'storage\\src\\test\\java\\org\\apache\\kafka\\tiered\\storage\\utils\\BrokerLocalStorage.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]}]

# %%
# convert into pandas with following headers FILE1, FILE2, window_24, window_48, window_72, window_168
import pandas as pd

def to_pandas(data):
    # Initialize a list to store the rows for the DataFrame
    rows = []

    # Process each item in the data to create a row for the DataFrame
    for item in data:
        row = {
            'FILE1': item['file_pair'][0],
            'FILE2': item['file_pair'][1],
            'window_24': 0,
            'window_48': 0,
            'window_72': 0,
            'window_168': 0
        }
        # Update the row with the commit counts for each time window
        for commit in item['coupled_commits']:
            time_window = commit['time_window']
            count = commit['commit_count']
            if time_window == 24:
                row['window_24'] += count
            elif time_window == 48:
                row['window_48'] += count
            elif time_window == 72:
                row['window_72'] += count
            elif time_window == 168:
                row['window_168'] += count

        rows.append(row)

    # Create a DataFrame from the rows
    df = pd.DataFrame(rows)

    return df

# %%
# sortby window 24
df = to_pandas(new_structure)
df.sort_values(by=['window_168'], ascending=False)
df
# Out:
#                                                  FILE1  \
# 0    core\src\main\java\kafka\log\remote\RemoteLogM...
# 1    core\src\main\java\kafka\log\remote\RemoteLogM...
# 2    core\src\main\java\kafka\log\remote\RemoteLogM...
# 3    core\src\main\java\kafka\log\remote\RemoteLogM...
# 4    core\src\main\java\kafka\log\remote\RemoteLogM...
# ..                                                 ...
# 336  connect\runtime\src\test\java\org\apache\kafka...
# 337  metadata\src\main\java\org\apache\kafka\contro...
# 338  metadata\src\main\java\org\apache\kafka\contro...
# 339  streams\src\main\java\org\apache\kafka\streams...
# 340  storage\src\test\java\org\apache\kafka\tiered\...
#
#                                                  FILE2  window_24  window_48  \
# 0    core\src\main\java\kafka\log\remote\RemoteLogM...          1          1
# 1    core\src\test\java\kafka\log\remote\RemoteLogM...          2          2
# 2    storage\api\src\main\java\org\apache\kafka\ser...          1          2
# 3    storage\src\main\java\org\apache\kafka\storage...          1          1
# 4    storage\src\test\java\org\apache\kafka\server\...          1          1
# ..                                                 ...        ...        ...
# 336  streams\src\main\java\org\apache\kafka\streams...          0          1
# 337  metadata\src\main\java\org\apache\kafka\contro...          1          1
# 338  streams\src\main\java\org\apache\kafka\streams...          0          1
# 339  streams\src\main\java\org\apache\kafka\streams...          1          1
# 340  storage\src\test\java\org\apache\kafka\tiered\...          1          1
#
#      window_72  window_168
# 0            1           1
# 1            2           2
# 2            2           2
# 3            1           1
# 4            1           1
# ..         ...         ...
# 336          1           1
# 337          1           1
# 338          1           1
# 339          1           1
# 340          1           1
#
# [341 rows x 6 columns]
