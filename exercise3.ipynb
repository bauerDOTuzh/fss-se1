# %% [markdown]
# # Preprocessing

# %%
# %pip install pydriller
# Out:
# Requirement already satisfied: pydriller in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (2.5.1)
# Requirement already satisfied: gitpython in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (3.1.40)
# Requirement already satisfied: pytz in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (2023.3.post1)
# Requirement already satisfied: types-pytz in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (2023.3.1.1)
# Requirement already satisfied: lizard in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (1.17.10)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from gitpython->pydriller) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->pydriller) (5.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydriller import Repository
import os
import datetime as dt
from datetime import timedelta

# %%
# Clone code from the repo and save it for code portability -> via normal git clone
url = "https://github.com/apache/kafka"
repo_path = os.path.join(os.getcwd(), 'kafka')
clone = f"git clone {url} {repo_path}" 

os.system(clone) # Cloning
# Out:
# 128

# %%
# checkout the tag 3.6.0
os.chdir(repo_path)
os.system("git checkout 3.6.0")
# back to the "home" folder
os.chdir("..")

# %%
from_tag = "3.5.1"
from_date=dt.datetime(2023, 7, 14, 18, 51, 0)

to_tag = "3.6.0"
to_date=dt.datetime(2023, 9, 29, 6, 56, 0)

# Using datetimes of the releases, since tags don't yield any commits
# Open question 
# repo = Repository(path_to_repo=repo_path, from_tag=to_tag, to_tag=from_tag)
repo = Repository(path_to_repo=repo_path, since=from_date, to=to_date)

# %% [markdown]
# # Exercise 3

# %%
# return array of files which were modified in following time horizon given the from_time
from datetime import timedelta
from collections import defaultdict

def get_mod_files_between(from_time, windows):
    results = {window: defaultdict(int) for window in windows}

    # Iterate through commits once, checking against each window
    for commit in Repository(path_to_repo=repo_path, since=from_time).traverse_commits():
        for file in commit.modified_files:
            filename = file.new_path if file.new_path else file.old_path

            if(not filename.endswith(".java")):
                continue


            # append into each suitable window
            for window in windows:
                window_end_time = from_time + timedelta(hours=window)
                if from_time <= commit.committer_date <= window_end_time:
                        results[window][filename] += 1

    # Convert defaultdict to regular dict for final output
    return {window: dict(file_dict) for window, file_dict in results.items()}

# %%
from collections import Counter
#iterate over each changes from the start of the repo?
# -> look in a windof of next commits within a window of X
# -> calculate the number of changes in this window

file_connections = defaultdict(lambda: {24: {}, 48: {}, 72: {}, 168: {}})
windows = [24, 48, 72, 168]
i = 1

for commit in Repository(path_to_repo=repo_path).traverse_commits():
    for file in commit.modified_files:
        filename = file.new_path if file.new_path else file.old_path

        #if not java files -> skip
        if(not filename.endswith(".java")):
            continue
        file_dict = file_connections[filename]

        mod_files_results = get_mod_files_between(commit.committer_date, windows)
        for window, mod_list in mod_files_results.items():
            file_dict[window] = dict(Counter(file_dict[window]) + Counter(mod_list))
                
    i -= 1
    if i <= 0:
        break

# %%
#This function has 2 assumptions 
#   -> we don't remove modification of the file itself in the array
#   -> we have an causality -> given modification of file 1 how many times was FILE2 modified in the time window
def generate_commit_structure(file_connections):
    output = {}
    # Collect data for each file pair across all time windows
    for file, time_windows in file_connections.items():
        for time_window, connections in time_windows.items():
            for connected_file, count in connections.items():
                file_pair = tuple(sorted([file, connected_file]))
                if file_pair not in output:
                    output[file_pair] = {}
                if time_window not in output[file_pair]:
                    output[file_pair][time_window] = 0
                output[file_pair][time_window] += count

    # Format the output
    formatted_output = []
    for file_pair, time_windows in output.items():
        coupled_commits = [{"time_window": tw, "commit_count": count} for tw, count in time_windows.items()]
        formatted_output.append({
            "file_pair": list(file_pair),
            "coupled_commits": coupled_commits
        })

    return formatted_output

# %%
#Test the transformation into Slides type of code
file_connections_test = {"FILE1": {12: {"FILE2": 1, "FILE3": 1, "FILE4": 5},
                                   24: {"FILE2": 1, "FILE3": 1, "FILE4": 5}},
                        "FILE4": {12: {"FILE2": 1, "FILE3": 1, "FILE41": 5}}}
new_structure = generate_commit_structure(file_connections_test)
new_structure
# Out:
# [{'file_pair': ['FILE1', 'FILE2'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 1},
#    {'time_window': 24, 'commit_count': 1}]},
#  {'file_pair': ['FILE1', 'FILE3'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 1},
#    {'time_window': 24, 'commit_count': 1}]},
#  {'file_pair': ['FILE1', 'FILE4'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 5},
#    {'time_window': 24, 'commit_count': 5}]},
#  {'file_pair': ['FILE2', 'FILE4'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 1}]},
#  {'file_pair': ['FILE3', 'FILE4'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 1}]},
#  {'file_pair': ['FILE4', 'FILE41'],
#   'coupled_commits': [{'time_window': 12, 'commit_count': 5}]}]

# %%
# transform repository into the structure for the slides
new_structure = generate_commit_structure(file_connections)

new_structure
# Out:
# [{'file_pair': ['CONTRIBUTORS', 'CONTRIBUTORS'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'LICENSE'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'NOTICE'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'README.md'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'bin\\kafka-console-consumer-log4j.properties'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-console-consumer.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-consumer-perf-test.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-consumer-shell.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-producer-perf-test.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-producer-shell.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-replay-log-producer.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-run-class.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-server-start.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-server-stop.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-simple-consumer-perf-test.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\kafka-simple-consumer-shell.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\zookeeper-server-start.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'bin\\zookeeper-server-stop.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\clojure\\.gitignore'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\clojure\\LICENSE'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\clojure\\README.md'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\clojure\\leiningen\\run_example.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\clojure\\project.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\clojure\\resources\\log4j.properties'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\clojure\\src\\kafka\\buffer.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\clojure\\src\\kafka\\example.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\clojure\\src\\kafka\\kafka.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\clojure\\src\\kafka\\print.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\clojure\\src\\kafka\\serializable.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\clojure\\src\\kafka\\types.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\clojure\\test\\kafka\\buffer_test.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\clojure\\test\\kafka\\print_test.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\clojure\\test\\kafka\\serializable_test.clj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\LICENSE'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\Makefile.am'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\Makefile.in'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\README.md'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\aclocal.m4'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\config.guess'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\config.sub'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\depcomp'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\install-sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\ltmain.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\m4\\libtool.m4'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\m4\\ltoptions.m4'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\m4\\ltsugar.m4'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\m4\\ltversion.m4'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\m4\\lt~obsolete.m4'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\build-aux\\missing'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\configure'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\configure.ac'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\src\\encoder.hpp'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\src\\encoder_helper.hpp'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\src\\example.cpp'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\src\\producer.cpp'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\src\\producer.hpp'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\cpp\\src\\tests\\encoder_helper_tests.cpp'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\cpp\\src\\tests\\encoder_tests.cpp'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\cpp\\src\\tests\\producer_tests.cpp'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\csharp\\.gitignore'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\csharp\\LICENSE'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\csharp\\README.md'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\csharp\\Settings.StyleCop'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\lib\\nunit\\2.5.9\\nunit.framework.dll'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\AbstractRequest.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Consumer.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Kafka.Client.csproj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\KafkaConnection.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\KafkaException.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Message.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Producer.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Properties\\AssemblyInfo.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Request\\FetchRequest.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Request\\MultiFetchRequest.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Request\\MultiProducerRequest.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Request\\OffsetRequest.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Request\\ProducerRequest.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\RequestContext.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\RequestType.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Util\\BitWorks.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Kafka.Client\\Util\\Crc32.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\csharp\\src\\Kafka\\Kafka.sln'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.IntegrationTests\\Kafka.Client.IntegrationTests.csproj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.IntegrationTests\\KafkaIntegrationTest.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.IntegrationTests\\Properties\\AssemblyInfo.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.Tests\\Kafka.Client.Tests.csproj'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.Tests\\MessageTests.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.Tests\\Properties\\AssemblyInfo.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.Tests\\Request\\FetchRequestTests.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.Tests\\Request\\MultiFetchRequestTests.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.Tests\\Request\\MultiProducerRequestTests.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.Tests\\Request\\OffsetRequestTests.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.Tests\\Request\\ProducerRequestTests.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\csharp\\src\\Kafka\\Tests\\Kafka.Client.Tests\\Util\\BitWorksTests.cs'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\.gitignore'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\LICENSE'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\Makefile'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\README.md'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\kafka_test.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\src\\consumer.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\src\\converts.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\src\\kafka.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\src\\message.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\src\\publisher.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\src\\request.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\src\\timing.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\tools\\consumer\\Makefile'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\tools\\consumer\\consumer.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\tools\\offsets\\Makefile'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\tools\\offsets\\offsets.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\tools\\publisher\\Makefile'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\go\\tools\\publisher\\publisher.go'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\LICENSE'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\README.md'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\src\\examples\\autoloader.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\src\\examples\\consume.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\src\\examples\\produce.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\lib\\Kafka\\BoundedByteBuffer\\Receive.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\lib\\Kafka\\BoundedByteBuffer\\Send.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\src\\lib\\Kafka\\Encoder.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\lib\\Kafka\\FetchRequest.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\src\\lib\\Kafka\\Message.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\lib\\Kafka\\MessageSet.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\src\\lib\\Kafka\\Producer.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\src\\lib\\Kafka\\Request.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\lib\\Kafka\\RequestKeys.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\lib\\Kafka\\SimpleConsumer.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\tests\\Kafka\\BoundedByteBuffer\\ReceiveTest.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\tests\\Kafka\\BoundedByteBuffer\\SendTest.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\tests\\Kafka\\EncoderTest.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\tests\\Kafka\\FetchRequestTest.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\tests\\Kafka\\MessageTest.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'clients\\php\\src\\tests\\Kafka\\ProducerTest.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\src\\tests\\bootstrap.php'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\php\\src\\tests\\phpunit.xml'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\python\\kafka.py'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\python\\setup.py'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\LICENSE'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\README.md'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\Rakefile'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\TODO'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\kafka-rb.gemspec'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\lib\\kafka.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\lib\\kafka\\batch.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\lib\\kafka\\consumer.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\lib\\kafka\\error_codes.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\lib\\kafka\\io.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\lib\\kafka\\message.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\lib\\kafka\\producer.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\lib\\kafka\\request_type.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\spec\\batch_spec.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\spec\\consumer_spec.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\spec\\io_spec.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\spec\\kafka_spec.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\spec\\message_spec.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\spec\\producer_spec.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'clients\\ruby\\spec\\spec_helper.rb'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'config\\consumer.properties'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'config\\log4j.properties'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'config\\server.properties'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'config\\zookeeper.properties'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['CONTRIBUTORS', 'contrib\\hadoop-consumer\\README'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'contrib\\hadoop-consumer\\copy-jars.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'contrib\\hadoop-consumer\\hadoop-setup.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\lib\\avro-1.4.0.jar'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\lib\\commons-logging-1.0.4.jar'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\lib\\hadoop-0.20.2-core.jar'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\lib\\jackson-core-asl-1.5.5.jar'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\lib\\jackson-mapper-asl-1.5.5.jar'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\lib\\pig-0.8.0-core.jar'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\lib\\piggybank.jar'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS', 'contrib\\hadoop-consumer\\run-class.sh'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\src\\main\\java\\kafka\\etl\\KafkaETLContext.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\src\\main\\java\\kafka\\etl\\KafkaETLInputFormat.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['CONTRIBUTORS',
#    'contrib\\hadoop-consumer\\src\\main\\java\\kafka\\etl\\KafkaETLJob.java'],
#   'coupled_commits': [{'time_window': 24, 'commit_count': 1},
#    {'time_window': 48, 'commit_count': 1},
#    {'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
# ...
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\message\\MessageSet.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\BoundedByteBufferReceive.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\BoundedByteBufferSend.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\ByteBufferSend.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\ConnectionConfig.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\Handler.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\InvalidRequestException.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\Request.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\SocketServer.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\SocketServerStats.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\network\\Transmission.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\BrokerPartitionInfo.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\ConfigBrokerPartitionInfo.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\DefaultPartitioner.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 3}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\KafkaLog4jAppender.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\Partitioner.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\Producer.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\ProducerConfig.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 3}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\ProducerData.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\SyncProducer.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\SyncProducerConfig.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\async\\AsyncProducer.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\async\\AsyncProducerConfig.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\async\\AsyncProducerStats.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\async\\AsyncProducerStatsMBean.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\async\\CallbackHandler.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\async\\EventHandler.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\async\\MissingConfigException.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\async\\QueueClosedException.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\producer\\async\\QueueFullException.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\serializer\\Decoder.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\serializer\\Encoder.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\server\\KafkaConfig.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\server\\KafkaRequestHandlers.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\server\\KafkaServer.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\server\\KafkaServerStartable.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\server\\MessageSetSend.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\server\\MultiMessageSetSend.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\tools\\ConsumerPerformance.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\tools\\ProducerPerformance.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\tools\\SimpleConsumerPerformance.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\tools\\SimpleConsumerShell.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\Annotations.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\DelayedItem.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\DumpLogSegments.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\IteratorTemplate.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\KafkaScheduler.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\MockTime.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\Pool.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\Range.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\Throttler.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\Time.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\main\\scala\\kafka\\utils\\Utils.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 2},
#    {'time_window': 168, 'commit_count': 2}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\test\\scala\\other\\kafka\\TestKafkaAppender.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\test\\scala\\other\\kafka\\TestLinearWriteSpeed.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\test\\scala\\other\\kafka\\TestLogPerformance.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\test\\scala\\other\\kafka\\TestTruncate.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\test\\scala\\unit\\kafka\\consumer\\TopicCountTest.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\test\\scala\\unit\\kafka\\integration\\AutoOffsetResetTest.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\test\\scala\\unit\\kafka\\integration\\BackwardsCompatibilityTest.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  {'file_pair': ['core\\src\\main\\scala\\kafka\\consumer\\ConsoleConsumer.scala',
#    'core\\src\\test\\scala\\unit\\kafka\\integration\\FetcherTest.scala'],
#   'coupled_commits': [{'time_window': 72, 'commit_count': 1},
#    {'time_window': 168, 'commit_count': 1}]},
#  ...]

# %%
# convert into pandas with following headers FILE1, FILE2, window_24, window_48, window_72, window_168
import pandas as pd

def to_pandas(data):
    # Initialize a list to store the rows for the DataFrame
    rows = []

    # Process each item in the data to create a row for the DataFrame
    for item in data:
        row = {
            'FILE1': item['file_pair'][0],
            'FILE2': item['file_pair'][1],
            'window_24': 0,
            'window_48': 0,
            'window_72': 0,
            'window_168': 0
        }
        # Update the row with the commit counts for each time window
        for commit in item['coupled_commits']:
            time_window = commit['time_window']
            count = commit['commit_count']
            if time_window == 24:
                row['window_24'] += count
            elif time_window == 48:
                row['window_48'] += count
            elif time_window == 72:
                row['window_72'] += count
            elif time_window == 168:
                row['window_168'] += count

        rows.append(row)

    # Create a DataFrame from the rows
    df = pd.DataFrame(rows)

    return df
# Out:
#                                                   FILE1  \
# 0                                          CONTRIBUTORS
# 1                                          CONTRIBUTORS
# 2                                          CONTRIBUTORS
# 3                                          CONTRIBUTORS
# 4                                          CONTRIBUTORS
# ...                                                 ...
# 3628  core\src\test\scala\unit\kafka\network\SocketS...
# 3629  core\src\test\scala\unit\kafka\network\SocketS...
# 3630  core\src\test\scala\unit\kafka\network\SocketS...
# 3631  core\src\test\scala\unit\kafka\network\SocketS...
# 3632  core\src\test\scala\unit\kafka\network\SocketS...
#
#                                                   FILE2  window_24  window_48  \
# 0                                          CONTRIBUTORS          1          1
# 1                                               LICENSE          1          1
# 2                                                NOTICE          1          1
# 3                                             README.md          1          1
# 4           bin\kafka-console-consumer-log4j.properties          1          1
# ...                                                 ...        ...        ...
# 3628  system_test\embedded_consumer\config\zookeeper...          0          0
# 3629  system_test\producer_perf\bin\run-compression-...          0          0
# 3630          system_test\producer_perf\bin\run-test.sh          0          0
# 3631  system_test\producer_perf\config\server.proper...          0          0
# 3632  system_test\producer_perf\config\zookeeper.pro...          0          0
#
#       window_72  window_168
# 0             1           1
# 1             1           1
# 2             1           1
# 3             1           1
# 4             1           1
# ...         ...         ...
# 3628          0           3
# 3629          0           3
# 3630          0           3
# 3631          0           3
# 3632          0           3
#
# [3633 rows x 6 columns]

# %%
# sortby window 24
df = to_pandas(new_structure)
df.sort_values(by=['window_24'], ascending=False)
df
# Out:
#                                                   FILE1  \
# 0                                          CONTRIBUTORS
# 1                                          CONTRIBUTORS
# 2                                          CONTRIBUTORS
# 3                                          CONTRIBUTORS
# 4                                          CONTRIBUTORS
# ...                                                 ...
# 3628  core\src\test\scala\unit\kafka\network\SocketS...
# 3629  core\src\test\scala\unit\kafka\network\SocketS...
# 3630  core\src\test\scala\unit\kafka\network\SocketS...
# 3631  core\src\test\scala\unit\kafka\network\SocketS...
# 3632  core\src\test\scala\unit\kafka\network\SocketS...
#
#                                                   FILE2  window_24  window_48  \
# 0                                          CONTRIBUTORS          1          1
# 1                                               LICENSE          1          1
# 2                                                NOTICE          1          1
# 3                                             README.md          1          1
# 4           bin\kafka-console-consumer-log4j.properties          1          1
# ...                                                 ...        ...        ...
# 3628  system_test\embedded_consumer\config\zookeeper...          0          0
# 3629  system_test\producer_perf\bin\run-compression-...          0          0
# 3630          system_test\producer_perf\bin\run-test.sh          0          0
# 3631  system_test\producer_perf\config\server.proper...          0          0
# 3632  system_test\producer_perf\config\zookeeper.pro...          0          0
#
#       window_72  window_168
# 0             1           1
# 1             1           1
# 2             1           1
# 3             1           1
# 4             1           1
# ...         ...         ...
# 3628          0           3
# 3629          0           3
# 3630          0           3
# 3631          0           3
# 3632          0           3
#
# [3633 rows x 6 columns]
