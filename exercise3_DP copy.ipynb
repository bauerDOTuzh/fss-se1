# %% [markdown]
# # Preprocessing

# %%
# %pip install pydriller
# Out:
# Requirement already satisfied: pydriller in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (2.5.1)
# Requirement already satisfied: gitpython in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (3.1.40)
# Requirement already satisfied: pytz in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (2023.3.post1)
# Requirement already satisfied: types-pytz in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (2023.3.1.1)
# Requirement already satisfied: lizard in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from pydriller) (1.17.10)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from gitpython->pydriller) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\adam\anaconda3\envs\utils_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython->pydriller) (5.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydriller import Repository
import os
import datetime as dt
from datetime import timedelta, datetime
import numpy as np

# %%
# Clone code from the repo and save it for code portability -> via normal git clone
url = "https://github.com/apache/kafka"
repo_path = os.path.join(os.getcwd(), 'kafka')
clone = f"git clone {url} {repo_path}" 

os.system(clone) # Cloning
# Out:
# 128

# %%
# checkout the tag 3.6.0
os.chdir(repo_path)
os.system("git checkout 3.6.0")
# back to the "home" folder
os.chdir("..")

# %%
from_tag = "3.5.1"
from_date=dt.datetime(2023, 7, 14, 18, 51, 0)

to_tag = "3.6.0"
to_date=dt.datetime(2023, 9, 29, 6, 56, 0)

# Using datetimes of the releases, since tags don't yield any commits
# Open question 
# repo = Repository(path_to_repo=repo_path, from_tag=to_tag, to_tag=from_tag)
repo = Repository(path_to_repo=repo_path, since=from_date, to=to_date)

# %% [markdown]
# # Exercise 3

# %%
# Create a matrix of all current java files
import os

def get_unique_java_files(directory):
    unique_files = set()
    for root, dirs, files in os.walk(directory):
        # print(root)
        # print(files)
        for file in files:
            if file.endswith(".java") or True: #Hotfix
                file_path = os.path.join(root, file)
                # remove the repo path from the file path
                file_path = file_path.replace(directory+"\\", "")
                unique_files.add(file_path)
    return list(unique_files)

# Replace 'your_repo_directory' with the path to your repository
unique_files = get_unique_java_files(repo_path)

# %%
def add_file_to_MATRIX(file):
    if file not in FILE_INDEX_MAP:
        print("Adding file to MATRIX: ", file)
        
        new_index = len(FILE_INDEX_MAP)
        FILE_INDEX_MAP[file] = new_index
        unique_files.append(file)  # Update the unique_files list
        
        for window in MATRIX:
            # Correctly expand each matrix to include the new file
            current_matrix = MATRIX[window]
            new_matrix_size = len(unique_files)
            new_matrix = np.zeros((new_matrix_size, new_matrix_size))
            # Copy the old matrix values into the new matrix
            new_matrix[:current_matrix.shape[0], :current_matrix.shape[1]] = current_matrix
            MATRIX[window] = new_matrix

# %%
#add them to shared indexes
def process_files(files):
    modified_file_indices = []
    for file in files:
        # TODO if you want to select only java files, do it there!
        # print(file.new_path if file.new_path else file.old_path)
        # Accessing filename correctly 
        filename = file.new_path if file.new_path else file.old_path
        add_file_to_MATRIX(filename) #check if file is already in the MATRIX, if not add it (issue for files which were created and are not in repo now)
        modified_file_indices.append(FILE_INDEX_MAP[filename])
    return modified_file_indices

# %%
def update_MATRIX2(files_current, files_others, window):
    # print("Updating MATRIX for window: ", window, " for files: ", files_current, files_others)
    for i in files_current:
            for j in files_others:
                if i != j:  # Skip incrementing for the same file
                    # print("Updating MATRIX for window: ", window, " for files: ", i, j)
                    MATRIX[window][i][j] += 1

# %%
time_windows = [24, 48, 72, 168]  # time windows in hours
MATRIX = {window: np.zeros((len(unique_files), len(unique_files))) for window in time_windows}
FILE_INDEX_MAP = {file: index for index, file in enumerate(unique_files)}

# %%
from collections import deque
from datetime import timedelta
all_commits = Repository(path_to_repo=repo_path, 
                        #  only_modifications_with_file_types=['.java'],
                         since=datetime(2023, 8, 20, 17, 59, 0)
                         ).traverse_commits()

commit_queue = deque()
for commit in all_commits:
        commit_data = (commit.committer_date, process_files(commit.modified_files))
        commit_queue.append(commit_data)

        # Check if the time span exceeds 168 hours
        if commit_queue[-1][0] - commit_queue[0][0] > timedelta(hours=168):
            # Start processing the queue
            while commit_queue:
                current_commit = commit_queue.popleft()
                files = current_commit[1]
                current_commit_time = current_commit[0]
                # Process files and update MATRIX for each time window


                #TODO can be done more efficient
                for window in time_windows:
                    # Determine adjacent files within the time window
                    adjacent_files = []
                    for (date, file_list) in commit_queue:
                        if current_commit_time - date <= timedelta(hours=window):
                            adjacent_files.append(file_list)

                    update_MATRIX2(files, adjacent_files, window)

                # Maintain the rolling window up to 168 hours
                while commit_queue and commit_queue[-1][0] - commit_queue[0][0] > timedelta(hours=168):
                    commit_queue.popleft()
# Out:
# Adding file to MATRIX:  core\src\main\scala\kafka\common\LongRef.scala
# Adding file to MATRIX:  storage\src\test\java\org\apache\kafka\tiered\storage\utils\ActionUtils.java

# %%
import pandas as pd

def MATRIX_to_dataframe(MATRIX, unique_files):
    df_list = []
    for window, matrix in MATRIX.items():
        df = pd.DataFrame(matrix, index=unique_files, columns=unique_files)
        df = df.stack().reset_index()
        df.columns = ['File1', 'File2', 'Count']
        df['Time_Window'] = window
        df_list.append(df)

    return pd.concat(df_list, ignore_index=True)

result_df = MATRIX_to_dataframe(MATRIX, unique_files)

# %%
# Example: Filter out pairs with zero counts
result_df = result_df[result_df['Count'] > 0]

# Sort, reset index, etc.
result_df = result_df.sort_values(by=['Count'], ascending=False).reset_index(drop=True)

# %%
# make file 1 and file2 display the whole name
pd.set_option('display.max_colwidth', None)
result_df.head(30)
# filtered_df = result_df[result_df['File1'].str.contains('RemoteLogManager.java')]
# filtered_df.head(30)
# Out:
#                                                                                           File1  \
# 0                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 1                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 2                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 3                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 4                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 5                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 6                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 7                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 8                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 9                                     core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 10                                    core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 11                                                                            docs\connect.html
# 12  storage\src\test\java\org\apache\kafka\tiered\storage\integration\PartitionsExpandTest.java
# 13  storage\src\test\java\org\apache\kafka\tiered\storage\integration\PartitionsExpandTest.java
# 14                                    core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 15                                                                            docs\connect.html
# 16  storage\src\test\java\org\apache\kafka\tiered\storage\integration\PartitionsExpandTest.java
# 17                                                                            docs\connect.html
# 18                                                                                docs\toc.html
# 19                                    core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 20                                    core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 21  storage\src\test\java\org\apache\kafka\tiered\storage\integration\PartitionsExpandTest.java
# 22                                                                                docs\toc.html
# 23                                    core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 24                                                                                docs\toc.html
# 25                                    core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 26                                                                                docs\toc.html
# 27                                                                            docs\connect.html
# 28                                    core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 29                                    core\src\main\java\kafka\log\remote\RemoteLogManager.java
#
#                                                                                              File2  \
# 0                                        core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 1                                        core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 2                                        core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 3                                        core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 4         storage\src\test\java\org\apache\kafka\server\log\remote\storage\LocalTieredStorage.java
# 5         storage\src\test\java\org\apache\kafka\server\log\remote\storage\LocalTieredStorage.java
# 6         storage\src\test\java\org\apache\kafka\server\log\remote\storage\LocalTieredStorage.java
# 7         storage\src\test\java\org\apache\kafka\server\log\remote\storage\LocalTieredStorage.java
# 8   storage\api\src\main\java\org\apache\kafka\server\log\remote\storage\RemoteStorageManager.java
# 9   storage\api\src\main\java\org\apache\kafka\server\log\remote\storage\RemoteStorageManager.java
# 10  storage\api\src\main\java\org\apache\kafka\server\log\remote\storage\RemoteStorageManager.java
# 11                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 12                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 13                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 14            metadata\src\main\java\org\apache\kafka\metadata\migration\KRaftMigrationDriver.java
# 15                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 16                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 17                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 18                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 19            metadata\src\main\java\org\apache\kafka\metadata\migration\KRaftMigrationDriver.java
# 20            metadata\src\main\java\org\apache\kafka\metadata\migration\KRaftMigrationDriver.java
# 21                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 22                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 23            metadata\src\main\java\org\apache\kafka\metadata\migration\KRaftMigrationDriver.java
# 24                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 25  storage\api\src\main\java\org\apache\kafka\server\log\remote\storage\RemoteStorageManager.java
# 26                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 27                                       core\src\main\java\kafka\log\remote\RemoteLogManager.java
# 28                                   core\src\test\java\kafka\log\remote\RemoteLogManagerTest.java
# 29                                   core\src\test\java\kafka\log\remote\RemoteLogManagerTest.java
#
#     Count  Time_Window
# 0    10.0          168
# 1    10.0           48
# 2    10.0           72
# 3    10.0           24
# 4     9.0           48
# 5     9.0          168
# 6     9.0           24
# 7     9.0           72
# 8     8.0           48
# 9     8.0           24
# 10    8.0           72
# 11    8.0           48
# 12    8.0          168
# 13    8.0           72
# 14    8.0           72
# 15    8.0           72
# 16    8.0           48
# 17    8.0           24
# 18    8.0           24
# 19    8.0           24
# 20    8.0           48
# 21    8.0           24
# 22    8.0          168
# 23    8.0          168
# 24    8.0           48
# 25    8.0          168
# 26    8.0           72
# 27    8.0          168
# 28    7.0           24
# 29    7.0           72
